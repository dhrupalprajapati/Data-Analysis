# %%
#import needed modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#  read csv file
df = pd.read_csv('DataAnalyst.csv')
df.head()
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
# ...

# %%
# numbers of rows and columns in df
df.shape
# Out:
# (2253, 16)

# %%
# quick information of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2253 non-null   int64
#  1   Job Title          2253 non-null   object
#  2   Salary Estimate    2253 non-null   object
#  3   Job Description    2253 non-null   object
#  4   Rating             2253 non-null   float64
#  5   Company Name       2252 non-null   object
#  6   Location           2253 non-null   object
#  7   Headquarters       2253 non-null   object
#  8   Size               2253 non-null   object
#  9   Founded            2253 non-null   int64
#  10  Type of ownership  2253 non-null   object
#  11  Industry           2253 non-null   object
#  12  Sector             2253 non-null   object
#  13  Revenue            2253 non-null   object
#  14  Competitors        2253 non-null   object
#  15  Easy Apply         2253 non-null   object
# ...

# %%
# check the columns having null values or not, if yes then count null values
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         1
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# Easy Apply           0
# dtype: int64

# %%
# shows all the columns
df.columns
# Out:
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply'],
#       dtype='object')

# %%
# drop column
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
# show 1st three rows using head method
df.head(3)
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
# 2                         Squarespace\n3.4  New York, NY  New York, NY
#
#                      Size  Founded       Type of ownership  \
# ...

# %%
df['Job Title'].head()
# Out:
# 0    Data Analyst, Center on Immigration and Justic...
# 1                                 Quality Data Analyst
# 2    Senior Data Analyst, Insights & Analytics Team...
# 3                                         Data Analyst
# 4                               Reporting Data Analyst
# Name: Job Title, dtype: object

# %%
# function to see job titles using list
job_titles = []
def count_posts(dataframe):
    for i in dataframe:
        job_titles.append(i.split(','))

count_posts(df['Job Title'])

# %%
job_titles
# Out:
# [['Data Analyst', ' Center on Immigration and Justice (CIJ)'],
#  ['Quality Data Analyst'],
#  ['Senior Data Analyst', ' Insights & Analytics Team [Customer Operations]'],
#  ['Data Analyst'],
#  ['Reporting Data Analyst'],
#  ['Data Analyst'],
#  ['Business/Data Analyst (FP&A)'],
#  ['Data Science Analyst'],
#  ['Data Analyst'],
#  ['Data Analyst', ' Merchant Health'],
#  ['Data Analyst'],
#  ['Data Analyst'],
#  ['DATA ANALYST'],
#  ['Senior Data Analyst'],
#  ['Investment Advisory Data Analyst'],
#  ['Sustainability Data Analyst'],
#  ['Data Analyst'],
#  ['Clinical Data Analyst'],
#  ['DATA PROGRAMMER/ANALYST'],
#  ['Data Analyst'],
#  ['Product Analyst', ' Data Science'],
#  ['Data Science Analyst'],
#  ['Data Analyst - Intex Developer'],
#  ['Data Analyst'],
#  ['Entry Level / Jr. Data Analyst'],
#  ['Data Analyst'],
#  ['Data + Business Intelligence Analyst'],
#  ['Data Analyst', ' Product'],
#  ['Data Analyst Entry Level'],
#  ['Data Analyst'],
#  ['Data Analyst'],
# ...

# %%
df.head(2)
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
#
#                    Size  Founded       Type of ownership  \
# 0  201 to 500 employees     1961  Nonprofit Organization
# 1      10000+ employees     1893  Nonprofit Organization
#
#                            Industry       Sector                     Revenue  \
# ...

# %%
# show 1st five rows of 'Salary Estimate' column
df['Salary Estimate'].head()
# Out:
# 0    $37K-$66K (Glassdoor est.)
# 1    $37K-$66K (Glassdoor est.)
# 2    $37K-$66K (Glassdoor est.)
# 3    $37K-$66K (Glassdoor est.)
# 4    $37K-$66K (Glassdoor est.)
# Name: Salary Estimate, dtype: object

# %%
# last two row data of 'Salary Estimate' column
df['Salary Estimate'].tail(2)
# Out:
# 2251    $78K-$104K (Glassdoor est.)
# 2252    $78K-$104K (Glassdoor est.)
# Name: Salary Estimate, dtype: object

# %%
# add new column from existing column in df
df['Salary Estimate($)'] = df['Salary Estimate'].apply(lambda x: x[:10])

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'Salary Estimate($)'],
#       dtype='object')

# %%
df.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# ...

# %%
# drop 'Salary Estimate' column
df.drop(columns=['Salary Estimate'],inplace=True)

# %%
df.head(2)
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
#
#                    Size  Founded       Type of ownership  \
# 0  201 to 500 employees     1961  Nonprofit Organization
# 1      10000+ employees     1893  Nonprofit Organization
#
#                            Industry       Sector                     Revenue  \
# 0                 Social Assistance   Non-Profit  $100 to $500 million (USD)
# ...

# %%
# view Rating as series
df.Rating
# Out:
# 0       3.2
# 1       3.8
# 2       3.4
# 3       4.1
# 4       3.9
#        ...
# 2248    2.5
# 2249    2.9
# 2250   -1.0
# 2251    3.1
# 2252    3.4
# Name: Rating, Length: 2253, dtype: float64

# %%
# see all unique ratings
df.Rating.unique()
# Out:
# array([ 3.2,  3.8,  3.4,  4.1,  3.9,  4.4,  3.7,  4. , -1. ,  3. ,  3.6,
#         4.9,  3.3,  3.5,  5. ,  4.8,  4.7,  4.6,  2.9,  1. ,  3.1,  4.5,
#         2.3,  4.2,  2.8,  4.3,  2.7,  2.5,  2.6,  2.4,  2. ,  2.1,  1.7,
#         2.2,  1.8,  1.6,  1.9])

# %%
# function to remove rating below 0
df.Rating = df.Rating.apply(lambda x: x if x >= 0 else 0)

# %%
df.Rating.unique()
# Out:
# array([3.2, 3.8, 3.4, 4.1, 3.9, 4.4, 3.7, 4. , 0. , 3. , 3.6, 4.9, 3.3,
#        3.5, 5. , 4.8, 4.7, 4.6, 2.9, 1. , 3.1, 4.5, 2.3, 4.2, 2.8, 4.3,
#        2.7, 2.5, 2.6, 2.4, 2. , 2.1, 1.7, 2.2, 1.8, 1.6, 1.9])

# %%
df.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
# ...

# %%
df.Founded
# Out:
# 0       1961
# 1       1893
# 2       2003
# 3       2002
# 4       2009
#         ...
# 2248      -1
# 2249    1935
# 2250      -1
# 2251    1984
# 2252    1864
# Name: Founded, Length: 2253, dtype: int64

# %%
# function to drop rows having year less then or equal to 0
df.drop(df[df['Founded']<=0].index,inplace=True)

# %%
df.Founded.unique()
# Out:
# array([1961, 1893, 2003, 2002, 2009, 2014, 2001, 1914, 1896, 2013, 1841,
#        1884, 2004, 2016, 1996, 1958, 2006, 1998, 1969, 2011, 2017, 2005,
#        1904, 2018, 1956, 2007, 1990, 1923, 2015, 1951, 1981, 2000, 1966,
#        1939, 1999, 1812, 1945, 1985, 1984, 1962, 1995, 2012, 1967, 1799,
#        1918, 1948, 1994, 1895, 1845, 1968, 2008, 1911, 1997, 1832, 1934,
#        1938, 1963, 1992, 1977, 1886, 1862, 1906, 1993, 1935, 1971, 1989,
#        1859, 1946, 1818, 1932, 1784, 1856, 1978, 1912, 1957, 1937, 1982,
#        1964, 1850, 1983, 1869, 1947, 1868, 1936, 1853, 2010, 1902, 1944,
#        1888, 1880, 1973, 1931, 1987, 2019, 1919, 1979, 1954, 1980, 1976,
#        1872, 1926, 1991, 1855, 1959, 1986, 1890, 1882, 1883, 1837, 1817,
#        1908, 1988, 1965, 1828, 1889, 1898, 1928, 1913, 1901, 1916, 1857,
#        1955, 1949, 1970, 1822, 1972, 1864, 1975, 1960, 1885, 1922, 1740,
#        1830, 1887, 1974, 1905, 1953, 1952, 1897, 1865, 1921, 1867, 1933,
# ...

# %%
df.shape
# Out:
# (1593, 15)

# %%
df.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
# ...

# %%
# function to remove 'employees' sufix from our columns data
df['Size'] = df['Size'].apply(lambda x : x[:-10])

# %%
df.Size.values
# Out:
# array(['201 to 500', '10000+', '1001 to 5000', ..., '10000+',
#        '201 to 500', '10000+'], dtype=object)

# %%
#  function to remove 'to' substring and replace it with '-' symbol in df
df['Size'] = df['Size'].apply(lambda x : ('-').join(x.split('to')))

# %%
df.Size
# Out:
# 0         201 - 500
# 1            10000+
# 2       1001 - 5000
# 3         201 - 500
# 4        501 - 1000
#            ...
# 2243         10000+
# 2245    1001 - 5000
# 2249         10000+
# 2251      201 - 500
# 2252         10000+
# Name: Size, Length: 1593, dtype: object

# %%
df.head(2)
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
#
#         Size  Founded       Type of ownership  \
# 0  201 - 500     1961  Nonprofit Organization
# 1     10000+     1893  Nonprofit Organization
#
#                            Industry       Sector                     Revenue  \
# 0                 Social Assistance   Non-Profit  $100 to $500 million (USD)
# 1  Health Care Services & Hospitals  Health Care      $2 to $5 billion (USD)
#
# ...

# %%
df['Easy Apply'].unique()
# Out:
# array(['True', '-1'], dtype=object)

# %%
# replace outlier with boolean values
df['Easy Apply'].replace({'-1':False,'True':True}, inplace=True)

# %%
df['Easy Apply'].unique()
# Out:
# array([ True, False])

# %%
df.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
# ...

# %%
df.Competitors.unique()
# Out:
# array(['-1', 'GoDaddy', 'DraftKings', 'Travelers, Chubb, Crum & Forster',
#        'Thomson Reuters, Hearst, Pearson', 'Signifyd, Forter',
#        'NewYork-Presbyterian Hospital, Northwell Health',
#        'DoubleClick, Specific Media, Collective',
#        'KPMG, Accenture, Deloitte', 'Microsoft, Apple, Facebook',
#        'Goldman Sachs, Commonwealth Bank of Australia, Deutsche Bank',
#        'Hired, Indeed, AngelList', 'Criteo, AppNexus, dataxu',
#        'News Corp, WarnerMedia, NBCUniversal',
#        'Soros Fund Management, D. E. Shaw & Co. - Investment Firm, Fortress Investment Group',
#        'Persistent Systems (India), GlobalLogic, Synechron',
#        'Google, Goldman Sachs, Thomson Reuters',
#        'MediaMath, Conversant, AppNexus',
#        'Fidelity Investments, BlackRock, Putnam Investments',
#        'Artech Information Systems, Mindlance, Tech Mahindra',
#        'Coleman Research, AlphaSights, Third Bridge',
# ...

# %%
df.Competitors.replace({'-1':'No Compititors'},inplace=True)

# %%
df.Competitors.unique()
# Out:
# array(['No Compititors', 'GoDaddy', 'DraftKings',
#        'Travelers, Chubb, Crum & Forster',
#        'Thomson Reuters, Hearst, Pearson', 'Signifyd, Forter',
#        'NewYork-Presbyterian Hospital, Northwell Health',
#        'DoubleClick, Specific Media, Collective',
#        'KPMG, Accenture, Deloitte', 'Microsoft, Apple, Facebook',
#        'Goldman Sachs, Commonwealth Bank of Australia, Deutsche Bank',
#        'Hired, Indeed, AngelList', 'Criteo, AppNexus, dataxu',
#        'News Corp, WarnerMedia, NBCUniversal',
#        'Soros Fund Management, D. E. Shaw & Co. - Investment Firm, Fortress Investment Group',
#        'Persistent Systems (India), GlobalLogic, Synechron',
#        'Google, Goldman Sachs, Thomson Reuters',
#        'MediaMath, Conversant, AppNexus',
#        'Fidelity Investments, BlackRock, Putnam Investments',
#        'Artech Information Systems, Mindlance, Tech Mahindra',
#        'Coleman Research, AlphaSights, Third Bridge',
# ...

# %%
df.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
# ...

# %%
df.Location.unique()
# Out:
# array(['New York, NY', 'Jersey City, NJ', 'Brooklyn, NY', 'Weehawken, NJ',
#        'Florham Park, NJ', 'Manhasset, NY', 'Queens Village, NY',
#        'Haworth, NJ', 'Fort Lee, NJ', 'Bronx, NY', 'Newark, NJ',
#        'Lake Success, NY', 'Summit, NJ', 'Berkeley Heights, NJ',
#        'Essex Fells, NJ', 'South Plainfield, NJ', 'Franklin Lakes, NJ',
#        'Mount Vernon, NY', 'Secaucus, NJ', 'Woodbridge, NJ',
#        'Parsippany, NJ', 'Whippany, NJ', 'Hoboken, NJ', 'West Orange, NJ',
#        'Iselin, NJ', 'Montvale, NJ', 'Salt Lake City, UT', 'Lehi, UT',
#        'Draper, UT', 'American Fork, UT', 'Reedley, CA', 'Hanford, CA',
#        'Hampton, VA', 'Norfolk, VA', 'Portsmouth, VA', 'Smithfield, VA',
#        'Suffolk, VA', 'Yorktown, VA', 'Chesapeake, VA', 'Fort Eustis, VA',
#        'Gainesville, FL', 'Alachua, FL', 'El Segundo, CA',
#        'Santa Monica, CA', 'Los Angeles, CA', 'Hermosa Beach, CA',
#        'Burbank, CA', 'Culver City, CA', 'Glendale, CA', 'Inglewood, CA',
# ...

# %%
df.head(2)
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
#
#         Size  Founded       Type of ownership  \
# 0  201 - 500     1961  Nonprofit Organization
# 1     10000+     1893  Nonprofit Organization
#
#                            Industry       Sector                     Revenue  \
# 0                 Social Assistance   Non-Profit  $100 to $500 million (USD)
# 1  Health Care Services & Hospitals  Health Care      $2 to $5 billion (USD)
#
# ...

# %%
df.dtypes
# Out:
# Job Title              object
# Job Description        object
# Rating                float64
# Company Name           object
# Location               object
# Headquarters           object
# Size                   object
# Founded                 int64
# Type of ownership      object
# Industry               object
# Sector                 object
# Revenue                object
# Competitors            object
# Easy Apply               bool
# Salary Estimate($)     object
# dtype: object
